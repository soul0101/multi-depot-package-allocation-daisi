# %%
import pydaisi as pyd

multi_depot_package_allocation = pyd.Daisi("soul0101/Multi-Depot Package Allocation")
# Out:
# [16:25:39] INFO     Calling                                                                          ]8;id=521747;file://c:\Users\91983\anaconda3\envs\face\lib\site-packages\pydaisi\pydaisi.py\pydaisi.py]8;;\:]8;id=820409;file://c:\Users\91983\anaconda3\envs\face\lib\site-packages\pydaisi\pydaisi.py#411\411]8;;\
#                     https://app.daisi.io/pebble-api/daisies/connect?name=soul0101/Multi-Depot
#                     Package Allocation
# [16:25:41] INFO     Found existing Daisi: 207cd7f4-c3be-41cb-ae91-50798d917ca4                       ]8;id=429570;file://c:\Users\91983\anaconda3\envs\face\lib\site-packages\pydaisi\pydaisi.py\pydaisi.py]8;;\:]8;id=438407;file://c:\Users\91983\anaconda3\envs\face\lib\site-packages\pydaisi\pydaisi.py#424\424]8;;\

# %%
# Load dummy data
depot_locations, drop_locations, depot_ids, drop_ids, depot_capacities = multi_depot_package_allocation.get_dummy_data().value

# Generate results
allocation_results = multi_depot_package_allocation.allocate_packages(depot_locations, drop_locations, depot_ids, drop_ids, depot_capacities).value

# Plot results
fig = multi_depot_package_allocation.get_allocations_plot_plotly(allocation_results).value
fig.show()
